# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/home/tim/Documents/W2026/stat486/STAT_486_final_proj/data/joined_with_tt_scores.csv")

# %%
train_df, test_df = train_test_split(df, test_size=0.5, random_state=42)

# %%
test_df.to_csv("data/supervised_split.csv")
